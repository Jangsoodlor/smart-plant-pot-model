# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from datetime import timedelta
from sklearn.metrics import root_mean_squared_error
import pickle

# %%
df = pd.read_csv("../dataset.csv", index_col="ts", parse_dates = True)
df.head()
# Out:
#                      id    light  temperature  soil_moisture  humidity  \
# ts
# 2025-04-01 21:15:00   1  34.3262      33.3125         3262.0        84
# 2025-04-01 21:30:00   2  33.9057      33.4688         3232.5        84
# 2025-04-01 21:45:00   3  33.2979      33.5938         3218.0        85
# 2025-04-01 22:00:00   4  33.6201      33.3281         3211.0        85
# 2025-04-01 22:15:00   5  33.2979      33.3438         3203.0        85
#
#                      api_temp  precipitation  cloud_cover
# ts
# 2025-04-01 21:15:00      27.9            0.1          100
# 2025-04-01 21:30:00      27.8            0.1          100
# 2025-04-01 21:45:00      27.8            0.1          100
# 2025-04-01 22:00:00      27.6            0.0          100
# 2025-04-01 22:15:00      27.6            0.0          100

# %%
daily_df = df.resample('D').mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 daily_df = df.resample('D').average()
#
# File c:\Users\krist\work\university\year2\semester2\data analysis\final-model\venv\Lib\site-packages\pandas\core\resample.py:215, in Resampler.__getattr__(self, attr)
#     212 if attr in self.obj:
#     213     return self[attr]
# --> 215 return object.__getattribute__(self, attr)
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'average'

# %%
daily_df
# Out:
#                id       light  temperature  soil_moisture  humidity  api_temp  \
# ts
# 2025-04-01     66    335.3356     368.3438       35321.50       923     310.2
# 2025-04-02   3174   1872.9905    2329.0004      217951.00      4321    2182.0
# 2025-04-03  12336   2487.2023    3214.5938      299661.50      7327    2855.3
# 2025-04-04  21552   2489.4246    3179.7503      309453.50      6946    2894.7
# 2025-04-05  30400  13407.2160    3211.5313      294410.00      6753    2876.9
# 2025-04-06  37583   2193.5648    3099.7342      285001.00      6690    2717.5
# 2025-04-07  48624   5860.8569    3153.0160      294069.83      7639    2773.4
# 2025-04-08  57840   2293.6989    3111.8594      300714.50      7485    2839.1
# 2025-04-09  53053   1777.3757    2473.4844      243224.00      5547    2368.6
# 2025-04-10  51782   1699.5595    2151.8434      212917.50      4951    2071.6
# 2025-04-11  81868   2346.0946    3061.3907      305108.00      7704    2823.9
# 2025-04-12  90288  10786.3481    3191.3748      303574.50      6905    2896.9
# 2025-04-13  99504   2477.7111    3260.3438      304747.50      7156    2936.3
# 2025-04-14  50945   1125.2296    1471.1718      143524.50      3889    1233.2
#
#             precipitation  cloud_cover
# ts
# 2025-04-01            0.3         1060
# 2025-04-02            0.0         6020
# 2025-04-03            2.4         7858
# 2025-04-04            0.0         3496
# 2025-04-05            0.0         6068
# 2025-04-06            0.0         5198
# 2025-04-07            3.1         5120
# 2025-04-08            2.5         7332
# 2025-04-09            0.4         4634
# 2025-04-10            0.8         6608
# 2025-04-11            4.6         9114
# 2025-04-12            0.0         6979
# 2025-04-13            0.1         6219
# 2025-04-14            2.8         4398
